# %%
# coding: utf-8
from pyknp import Juman
jumanpp = Juman()   # default is JUMAN++: Juman(jumanpp=True). if you use JUMAN, use Juman(jumanpp=False)
result = jumanpp.analysis("サクワッチ")
for mrph in result.mrph_list(): # 各形態素にアクセス
    print("見出し:%s, 読み:%s, 原形:%s, 品詞:%s, 品詞細分類:%s, 活用型:%s, 活用形:%s, 意味情報:%s, 代表表記:%s" \
            % (mrph.midasi, mrph.yomi, mrph.genkei, mrph.hinsi, mrph.bunrui, mrph.katuyou1, mrph.katuyou2, mrph.imis, mrph.repname))
# Out:
# 見出し:サクワッチ, 読み:サクワッチ, 原形:サクワッチ, 品詞:未定義語, 品詞細分類:カタカナ, 活用型:*, 活用形:*, 意味情報:品詞推定:名詞, 代表表記:

# %%
from pyknp import KNP
import re
text = '任天堂'
knp = KNP(option='-simple')     # Default is JUMAN++. If you use JUMAN, use KNP(jumanpp=False)
result = knp.parse(text)


print("文節")
for bnst in result.bnst_list(): # 各文節へのアクセス
    setu_f = re.split("[><]", bnst.fstring)
    del setu_f[::2]
    print("\tID:%d, 見出し:%s, 係り受けタイプ:%s, 親文節ID:%d, 素性:%s" \
            % (bnst.bnst_id, "".join(mrph.midasi for mrph in bnst.mrph_list()), bnst.dpndtype, bnst.parent_id, setu_f))

print("基本句")
for tag in result.tag_list(): # 各基本句へのアクセス
    ku_f = re.split("[><]", tag.fstring)
    del ku_f[::2]
    print("\tID:%d, 見出し:%s, 係り受けタイプ:%s, 親基本句ID:%d, 素性:%s" \
            % (tag.tag_id, "".join(mrph.midasi for mrph in tag.mrph_list()), tag.dpndtype, tag.parent_id, ku_f))

print("形態素")
for mrph in result.mrph_list(): # 各形態素へのアクセス
    so_f = re.split("[-:]", mrph.imis)
    print("\tID:%d, 見出し:%s, 読み:%s, 原形:%s, 品詞:%s, 品詞細分類:%s, 活用型:%s, 活用形:%s, 意味情報:%s, 代表表記:%s" \
            % (mrph.mrph_id, mrph.midasi, mrph.yomi, mrph.genkei, mrph.hinsi, mrph.bunrui, mrph.katuyou1, mrph.katuyou2, so_f, mrph.repname))
# Out:
# 文節
# 	ID:0, 見出し:任天堂, 係り受けタイプ:D, 親文節ID:-1, 素性:['体言', '用言:判']
# 基本句
# 	ID:0, 見出し:任天堂, 係り受けタイプ:D, 親基本句ID:-1, 素性:['体言', '用言:判', 'NE:ORGANIZATION:任天堂', '格解析結果:ガ/-']
# 形態素
# 	ID:0, 見出し:任天堂, 読み:にんてんどう, 原形:任天堂, 品詞:名詞, 品詞細分類:組織名, 活用型:*, 活用形:*, 意味情報:['代表表記', '任天堂/にんてんどう'], 代表表記:任天堂/にんてんどう

# %%
f = open('./talk2.srt') #キャプション読み込み
lines = f.readlines() # 1行毎にファイル終端まで全て読む(改行文字も含まれる)
f.close()
text0 = []
text2 = []

#不要な部分を除外
for i in range(2,len(lines),2):
    text0.append(lines[i])
    
for i in range(0,round(len(text0)),2):
    
    text3=''.join(text0[i].splitlines())
    text2.append(text3)

#連結
text = ''.join(text2)
#text = '箱根の駅伝があるということで'
print(text)
# Out:
よねえええ会で1年雰囲気がたねもう最初の10より10秒0で使う金使ってましたねつかんらしいはいもうそろ微熱かんだなっていうのねコツはてるわからんもうねふたりにポップなオーナーだ a 4 a震災時から見えるぞかまいたちのこのメーターは僕はもういいっ何十回も聴いてますけど今外の咳が一番ええ数あるらしかったねここで一番だしましたが多い気がしました震えるぐらい面白かったですね一言一句完璧なんだけどaこの犯的で93はないよってこう言われるんですよあっじゃあそのシーンはマーゴ店させたいとはいニューヨークと僕の中で100点は絶対ないんですよね100だったらその後漫才師がもっと良かった100いないからはしかに95度全然良かったと思いますああなる岡林さんにはただ僕のごめんなさいで芯材の中でトップ3組がちゃんとロボってくれて決勝でその1は思う奴が優勝してくれた海とこの93が十分残るやろうというちょっと感覚だったその時点だ何ですかなるほど可愛らしさにはなんかちょっとそういうオーラがもう2番手だと完ぺきでしたああっあああありがとうございますうさついてさまで敗者復活なんですけどもまぁ正直巨人しようって本当に敗者復活枠の人たちの音かも見られてるじゃないですか直上も言いますねそうですよの中で叙事詩の中でここ上がってくるんちゃうかなって思われたりしてたんですかまあ4言ったんですよオンライン自体は9敗here till アーサーああああっねこれはね人気東 m あるんですまあ正直視聴者さんのまあうまいことできますよねあれさんとに選べるんでそうですねえランマーリンギ投票もあるもちろん前のもう前提ですけど絵本を ...

# %%
import CaboCha
from pyknp import KNP
import re
import collections
import os
import hashlib

def make_answer(sentence)

    When = []
    Where = []
    What = []
    Why = []
    Who = []
    How = []
    w = []
    c = CaboCha.Parser('-d /usr/local/lib/mecab/dic/mecab-ipadic-neologd')

    words = []
    poss = []
    chunkId = [] 
    toId = []
    ID = -1
    scores = []
    howId = []
    who_start=[]
    what_start=[]
    when_start=[]
    where_start=[]
    why_start=[]
    how_start=[]

    nani = ['は','が','を','の','に','と'] #Whatの後に続く助詞
    naze =['だから', 'それで', 'そのため', 'このため', 'そこで', 'したがって', 'ゆえに', 'それゆえに','から','んで','ため','ので']#Whyの後に続く接続助詞


    tree =  c.parse(sentence) 
    knp = KNP(option='-tab')     # Default is JUMAN++. If you use JUMAN, use KNP(jumanpp=False)
    result = knp.parse(sentence)

    
    answers = collections.namedtuple("answers",
                                   ["who_text", "who_start"=-1,"what_start","where_text","where_start",
                                    "when_text","when_start","why_text","why_start","how_text","how_start"])

    for i in range(0, tree.size()):
        token = tree.token(i)
        #単語を取得
        word = token.surface
        words.append(word) #文字をスタック
        #品詞を取得
        pos = token.feature.split(",")
        poss.append(pos) #品詞をスタック

        #チャンクID, かかり先ID, スコアを取得
        if token.chunk != None:
                ID += 1
                ID2 = token.chunk.link
                score  = token.chunk.score
        chunkId.append(ID)
        scores.append(score)
        toId.append(ID2)


    for mrph in result.mrph_list(): # 各形態素へのアクセス

        so_f = re.split("[-:]", mrph.imis) #feature分割

        if mrph.bunrui == '地名' or '場所' in so_f:
            Where.append(mrph.midasi)

        elif '人' in so_f or '人名' in so_f or mrph.bunrui == '人名':
            Who.append(mrph.midasi)

    for bnst in result.bnst_list(): # 各文節へのアクセス2
        setu_f = re.split("[><]", bnst.fstring)
        del setu_f[::2]
        if '時間' in setu_f:
            When.append("".join(mrph.midasi for mrph in bnst.mrph_list()))

    num = len(words)-1
    while num > -1:

    ##Why##
        for c in naze:  
            if words[num] == c: #続く助詞がWhyの後に続くものの場合
                
                w.insert(0,words[num])
                nowId = chunkId[num] #最初のチャンクIDを保存

                while num>0:

                    if chunkId[num-1] != nowId and toId[num-1] > nowId and words[num-1] != '(': #今のチャンクIdが最初のIdでなく, かかり先Idが最初のId出ない
                        break
                    num -=1
                    w.insert(0,words[num])
                Why.insert(0,''.join(w))
                w = []


        if words[num] == 'に' and words[num-1] == 'ため':
            w.insert(0,words[num])
            nowId = chunkId[num] #最初のチャンクIDを保存
            num -=1
            while num>-1:

                if chunkId[num-1] != nowId and toId[num-1] > nowId and words[num-1] != '(': #今のチャンクIdが最初のIdでなく, かかり先Idが最初のId出ない
                    break
                w.insert(0,words[num])   
                num -=1
            Why.insert(0,''.join(w))
            w = []        
    ####    


    ##How##    
        elif toId[num] == -1 or words[num] == '。':
            w.insert(0, words[num])
            howId.append(chunkId[num])
            num -= 1
            while num > -1:
                if poss[num][0] =='助詞'and poss[num-1][0] != '動詞':
                    break
                w.insert(0,words[num])
                howId.append(chunkId[num])
                num -=1

            How.insert(0, ''.join(w))
            w=[]
    ####


    ##What## 

        elif toId[num] in howId and (poss[num][1] == '係助詞' or poss[num][1] == '格助詞' or (poss[num][1] == '接続助詞')) and (words[num] in nani): 

            w.insert(0,words[num])
            whatId = chunkId[num]
            num -= 1
     #       while num > -1:
    #            if chunkId[num] != whatId:
    #
     #               if ((toId[num] != whatId) and (toId[num] in howId == False)) or (poss[num][0] == '助詞' and (poss[num][1] != '係助詞' and poss[num][1] != '格助詞' and poss[num][1] != '終助詞')):
     #                   break
        #            elif scores[num] > 1.5:
     #           w.insert(0, words[num])
       #         num -= 1

            while chunkId[num] == chunkId[num-1]:
                w.insert(0, words[num])
                num -= 1

            w.insert(0, words[num])       
            What.insert(0,''.join(w))
            w = []
    ####    
        else:
            num -= 1

sentence = 'liteになっても空冷ファンが外れなかったのは残念。'
buf = ''
while len(buf) < 20:
    buf += hashlib.md5(os.urandom(100)).hexdigest()

paragraph = collections.namedtuple("paragraph",
                                    ["text","ID","answers"])
dataset = []
dataset.append(paragraph(text = sentence, ID = buf,answers = ))
# Out:
# Who:[]
# Where:[]
# When:[]
# Why:[]
# What:['外れなかったのは']
# How:['残念。']

# %%
import CaboCha
from pyknp import KNP
import re
import collections
import os
import hashlib

def make_answer(sentence):

    When = []
    Where = []
    What = []
    Why = []
    Who = []
    How = []
    w = []
    c = CaboCha.Parser('-d /usr/local/lib/mecab/dic/mecab-ipadic-neologd')

    words = []
    poss = []
    chunkId = [] 
    toId = []
    ID = -1
    scores = []
    howId = []



    nani = ['は','が','を','の','に','と'] #Whatの後に続く助詞
    naze =['だから', 'それで', 'そのため', 'このため', 'そこで', 'したがって', 'ゆえに', 'それゆえに','から','んで','ため','ので']#Whyの後に続く接続助詞


    tree =  c.parse(sentence) 

    result = knp.parse(sentence)

    
    answers = {"who_text":None, "who_start":-1,"what_text":None,"what_start":-1,"where_text":None,"where_start":-1,
                                    "when_text":None,"when_start":-1,"why_text":None,"why_start":-1,"how_text":None,"how_start":-1}

    for i in range(0, tree.size()):
        token = tree.token(i)
        #単語を取得
        word = token.surface
        words.append(word) #文字をスタック
        #品詞を取得
        pos = token.feature.split(",")
        poss.append(pos) #品詞をスタック

        #チャンクID, かかり先ID, スコアを取得
        if token.chunk != None:
                ID += 1
                ID2 = token.chunk.link
                score  = token.chunk.score
        chunkId.append(ID)
        scores.append(score)
        toId.append(ID2)



    num = len(words)-1
    while num > -1:

    ##Why##
        for c in naze:  
            if words[num] == c: #続く助詞がWhyの後に続くものの場合
       
                w.insert(0,words[num])
                nowId = chunkId[num] #最初のチャンクIDを保存

                while num>0:

                    if chunkId[num-1] != nowId and toId[num-1] > nowId and words[num-1] != '(': #今のチャンクIdが最初のIdでなく, かかり先Idが最初のId出ない
                        break
                    num -=1
                    w.insert(0,words[num])
                    answers["why_start"]= num
                Why.insert(0,''.join(w))
                w = []


        if words[num] == 'に' and words[num-1] == 'ため':
            w.insert(0,words[num])
            nowId = chunkId[num] #最初のチャンクIDを保存
            num -=1
            while num>-1:

                if chunkId[num-1] != nowId and toId[num-1] > nowId and words[num-1] != '(': #今のチャンクIdが最初のIdでなく, かかり先Idが最初のId出ない
                    break
                w.insert(0,words[num])   
                answers["why_start"]= num
                num -=1
            Why.insert(0,''.join(w))
            w = []        
    ####    


    ##How##    
        elif toId[num] == -1 or words[num] == '。':
            w.insert(0, words[num])
            howId.append(chunkId[num])
            num -= 1
            while num > -1:
                if poss[num][0] =='助詞'and poss[num-1][0] != '動詞':
                    break
                w.insert(0,words[num])
                answers["how_start"]= num
                howId.append(chunkId[num])
                num -=1

            How.insert(0, ''.join(w))
            w=[]
    ####


    ##What## 

        elif toId[num] in howId and (poss[num][1] == '係助詞' or poss[num][1] == '格助詞' or (poss[num][1] == '接続助詞')) and (words[num] in nani): 

            w.insert(0,words[num])
            whatId = chunkId[num]
            num -= 1
     #       while num > -1:
    #            if chunkId[num] != whatId:
    #
     #               if ((toId[num] != whatId) and (toId[num] in howId == False)) or (poss[num][0] == '助詞' and (poss[num][1] != '係助詞' and poss[num][1] != '格助詞' and poss[num][1] != '終助詞')):
     #                   break
        #            elif scores[num] > 1.5:
     #           w.insert(0, words[num])
       #         num -= 1

            while chunkId[num] == chunkId[num-1]:
                w.insert(0, words[num])
                num -= 1

            w.insert(0, words[num])   
            answers["what_start"]= num
            What.insert(0,''.join(w))
            w = []
    ####    
        else:
            num -= 1
    answers["who_text"] = Who;
    answers["what_text"] = What;
    answers["why_text"] = Why;
    answers["how_text"] = How;

    return(answers)

# %%
import random
import csv
import re


S = []
with open('./text/livedoor.tsv') as f1:
    l=f1.readlines()
    leng = len(l)
    L=random.sample(l,leng)
    for row in L:
        row_l = row.split('\t')
        tmp = re.sub('\u3000', "", row_l[1].split(' ')[0])
        tmp = re.sub('!!', "", tmp)
        tmp = re.sub('!?', "", tmp)
        S.append(tmp)
# Out:
# 今月もこんにちは、独女の皆様。お下劣、毒舌、春満喫！ドロンジョーヌ恩田です。

# %%
dataset = []
for sen in S[0:100]:

    sentence = sen


    buf = ''
    while len(buf) < 20:
        buf += hashlib.md5(os.urandom(100)).hexdigest()
    answers = make_answer(sentence)
    paragraph = {"text":sentence,"ID":buf,"answers":answers}
    dataset.append(paragraph)

# %%
print(dataset)
# Out:
# [{'text': 'クリスマスが近づくにつれて、活気づいてくる恋愛事情。', 'ID': '307949b5d707b7e97cd9a9989dd874c0', 'answers': {'who_text': [], 'who_start': -1, 'what_text': ['クリスマスが'], 'what_start': 0, 'where_text': None, 'where_start': -1, 'when_text': None, 'when_start': -1, 'why_text': [], 'why_start': -1, 'how_text': ['近づくにつれて、活気づいてくる恋愛事情。'], 'how_start': 2}}, {'text': '「プリティ・ウーマン」監督最新作、バレンタインデーのロサンゼルスを舞台に、恋愛と完璧なバレンタインを求める老若男女のラブストーリーを描いた映画「バレンタインデー」。冬に観たいラブロマンスとして話題を集める本作と、全国のハーゲンダッツショップとの甘〜いコラボレーションが決定しました。', 'ID': '4a1c4ed32822c1cc1586e820bfd28bce', 'answers': {'who_text': ['プリティ', 'バレンタイン', 'バレンタイン', '老若', 'バレンタイン'], 'who_start': -1, 'what_text': ['舞台に', 'ラブストーリーを', 'コラボレーションが'], 'what_start': 10, 'where_text': None, 'where_start': -1, 'when_text': None, 'when_start': -1, 'why_text': [], 'why_start': -1, 'how_text': ['描いた映画「バレンタインデー」。', '決定しました。'], 'how_start': 24}}, {'text': '公開3カ月前にして異例のキャンペーンを実施！ゴッサム・シティの悪を滅ぼす闇の騎士ダークナイトを描いた映画『ダークナイト』の待望の続編『ダークナイト', 'ID': '9103bc984c6dfa65ab7c39b1cc16c859', 'answers': {'who_text': ['騎士'], 'who_start': -1, 'what_text': [], 'what_start': -1, 'where_text': None, 'where_start': -1, 'when_text': None, 'when_start': -1, 'why_text': [], 'why_start': -1, 'how_text': ['続編『ダークナイト'], 'how_start': 31}}, {'text': 'レノボ・ジャパンより、デスクトップ代わりになる高性能ノートパソコン「IdeaPad', 'ID': '62bb4e5a0410fd3fad0ff6adbc2b2683', 'answers': {'who_text': [], 'who_start': -1, 'what_text': ['デスクトップ代わりに'], 'what_start': 3, 'where_text': None, 'where_start': -1, 'when_text': None, 'when_start': -1, 'why_text': [], 'why_start': -1, 'how_text': ['なる高性能ノートパソコン「IdeaPad'], 'how_start': 6}}, {'text': 'ゲームポータルサイト「Bigpoint.com」で遊べる「Darkorbit」というゲームは基本的に無料で遊べる。このゲームの中で販売された10万円のアイテムがなんと２０００個も売れたということでネット上で話題になっている。', 'ID': '8de9d65ff0308e13c47f9309e25c8ff4', 'answers': {'who_text': [], 'who_start': -1, 'what_text': ['ゲームは', '基本的に', '話題に'], 'what_start': 12, 'where_text': None, 'where_start': -1, 'when_text': None, 'when_start': -1, 'why_text': [], 'why_start': -1, 'how_text': ['遊べる。', 'なっている。'], 'how_start': 18}}, {'text': '（文＝小沢コージ）', 'ID': 'f20d94b74ddb2c60fb389f863180df9d', 'answers': {'who_text': ['小沢コージ'], 'who_start': -1, 'what_text': [], 'what_start': -1, 'where_text': None, 'where_start': -1, 'when_text': None, 'when_start': -1, 'why_text': [], 'why_start': -1, 'how_text': ['（文＝小沢コージ）'], 'how_start': 0}}, {'text': 'リドリー・スコット監督最新作『プロメテウス』のワールド・プレミアが、現地時間5月31日に、ロンドンのレスター・スクウェアにて開催された。', 'ID': '78d5f3e677b2d98cc8d3ec9837001c41', 'answers': {'who_text': ['スコット'], 'who_start': -1, 'what_text': ['ワールド・プレミアが', '現地時間5月31日に'], 'what_start': 7, 'where_text': None, 'where_start': -1, 'when_text': None, 'when_start': -1, 'why_text': [], 'why_start': -1, 'how_text': ['開催された。'], 'how_start': 20}}, {'text': 'ライフジャケットのような服が', 'ID': 'd1dee1020d42c28491164ed1ae01ffac', 'answers': {'who_text': [], 'who_start': -1, 'what_text': [], 'what_start': -1, 'where_text': None, 'where_start': -1, 'when_text': None, 'when_start': -1, 'why_text': [], 'why_start': -1, 'how_text': ['ような服が'], 'how_start': 2}}, {'text': '新入社員が入社してもうすぐ1ヶ月が経とうとしています。早い会社ではすでに配属が決まっているでしょうし、5月のゴールデンウィークが明ければ後輩たちは本格的に職場へと投入されていきます。', 'ID': '44f6ce4c8ac555ac6aa080fa053ac16c', 'answers': {'who_text': [], 'who_start': -1, 'what_text': ['1ヶ月が', '経とうと', '後輩たちは', '本格的に', '職場へと'], 'what_start': 6, 'where_text': None, 'where_start': -1, 'when_text': None, 'when_start': -1, 'why_text': [], 'why_start': -1, 'how_text': ['しています。', '投入されていきます。'], 'how_start': 12}}, {'text': '“14歳で妊娠、出産すると同時に母親に子供を奪われ（養子に出され）、それ以来二度と恋愛することもなく、心を閉ざしてしまったカレン（アネット・ベニング）51歳”', 'ID': '0147c3d9fbf83cc679cad151c7505e1f', 'answers': {'who_text': ['子供'], 'who_start': -1, 'what_text': ['心を'], 'what_start': 33, 'where_text': None, 'where_start': -1, 'when_text': None, 'when_start': -1, 'why_text': [], 'why_start': -1, 'how_text': ['閉ざしてしまったカレン（アネット・ベニング）51歳”'], 'how_start': 35}}, {'text': '2日、お笑いコンビ“ずん”のやす(42)がフジテレビのバラエティー番組「とんねるずのみなさんのおかげでした」の収録中に事故に遭い、第2腰椎破裂骨折などのケガを負ったとサンケイスポーツなどが報じ、ネット掲示板で波紋を呼んでいる。', 'ID': '6a511fd403b8964f20291ffc0c2e0f90', 'answers': {'who ...

# %%
text = 'コミュ力を上げることではなくて不安を解消する方法です'

from pyknp import KNP
import re
When = []
Where = []
What = []
Why = []
Who = []
How = []
nani = ['ガ','ヲ','ノ','ハ'] #Whatの後に続く助詞

knp = KNP(option='-tab')     # Default is JUMAN++. If you use JUMAN, use KNP(jumanpp=False)
result = knp.parse(text)


for mrph in result.mrph_list(): # 各形態素へのアクセス
    
    so_f = re.split("[-:]", mrph.imis) #feature分割
    
    if mrph.bunrui == '地名' or '場所' in so_f:
        Where.append(mrph.midasi)
    
    elif '人' in so_f or '人名' in so_f:
        Who.append(mrph.midasi)
        
for bnst in result.bnst_list(): # 各文節へのアクセス1
    setu_f = re.split("[><]", bnst.fstring)
    del setu_f[::2]
    
    if '主節' in setu_f:
        How.append("".join(mrph.midasi for mrph in bnst.mrph_list()))
        how_id = bnst.bnst_id
    if bnst.parent_id == how_id and '用言' in bnst.fstring:
        
        num = bnst.bnst_id
        while num > -1:
            
            How.insert(0,"".join(mrph.midasi for mrph in result.bnst_list()[num].mrph_list()))
            num -=1        
            if ('用言' in result.bnst_list()[num].fstring) == 0:
                break

        
for bnst in result.bnst_list(): # 各文節へのアクセス2
    setu_f = re.split("[><]", bnst.fstring)
    del setu_f[::2]
    if '時間' in setu_f:
        When.append("".join(mrph.midasi for mrph in bnst.mrph_list()))
    
       
    elif '格要素' in setu_f and bnst.parent_id == how_id:
        for c in nani:
            if c in setu_f:
                What.append("".join(mrph.midasi for mrph in bnst.mrph_list()))
#    elif bnst.parent_id == how_id and 
            
print('Who:%s' %(Who))
print('Where:%s' %(Where))
print('When:%s' %(When))
print('What:%s' %(What))
print('How:%s' %(How))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-83-d1cf24be1c25> in <module>
#      32         How.append("".join(mrph.midasi for mrph in bnst.mrph_list()))
#      33         how_id = bnst.bnst_id
# ---> 34     if bnst.parent_id == how_id and '用言' in bnst.fstring:
#      35
#      36         num = bnst.bnst_id
#
# NameError: name 'how_id' is not defined
